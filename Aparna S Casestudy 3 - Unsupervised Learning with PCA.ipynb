# %% [markdown]
# # PCA With Unsupervised Learning
#
#
# #### Dataset - 'Wholesale customers data.csv'
#
#
# The Whole sale customer data is given
# 1. Read the dataset to the python environment.
# 2. Try out different clustering models in the Whole sale customer dataset.
# 3. Find the optimum number of clusters in each model and create the model with the optimum number of clusters.
# 4. Perform PCA for Dimensionality reduction.

# %%
# importing necessary directories
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import matplotlib.cm as cm

#code to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Get data from the dataset
df=pd.read_csv('Wholesale customers data.csv')

# %%
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
df.shape
# Out:
# (440, 8)

# %% [markdown]
# ## Preprocessing

# %%
# Checking for missing values
df.isna().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Channel           440 non-null    int64
#  1   Region            440 non-null    int64
#  2   Fresh             440 non-null    int64
#  3   Milk              440 non-null    int64
#  4   Grocery           440 non-null    int64
#  5   Frozen            440 non-null    int64
#  6   Detergents_Paper  440 non-null    int64
#  7   Delicassen        440 non-null    int64
# dtypes: int64(8)
# memory usage: 27.6 KB

# %% [markdown]
# There are no missing values or null values and the dtypes is int64 for all 8 columns.

# %%
df['Channel'].value_counts()
# Out:
# 1    298
# 2    142
# Name: Channel, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# 3    316
# 1     77
# 2     47
# Name: Region, dtype: int64

# %%
df.describe()
# Out:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  440.000000  440.000000     440.000000    440.000000    440.000000
# mean     1.322727    2.543182   12000.297727   5796.265909   7951.277273
# std      0.468052    0.774272   12647.328865   7380.377175   9503.162829
# min      1.000000    1.000000       3.000000     55.000000      3.000000
# 25%      1.000000    2.000000    3127.750000   1533.000000   2153.000000
# 50%      1.000000    3.000000    8504.000000   3627.000000   4755.500000
# 75%      2.000000    3.000000   16933.750000   7190.250000  10655.750000
# max      2.000000    3.000000  112151.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_Paper    Delicassen
# count    440.000000        440.000000    440.000000
# mean    3071.931818       2881.493182   1524.870455
# std     4854.673333       4767.854448   2820.105937
# min       25.000000          3.000000      3.000000
# ...

# %% [markdown]
# We need to further investigate for outliers. If outliers are present we need to use some kind of scaling/normalisation/standardisation technique to deal with it instead of IQR.

# %% [markdown]
# ## Outlier Detection

# %%
df1 = df.copy(deep=True)

# %%
# dropping Channel and Region as they do not have outliers
df1.drop(df1[['Channel', 'Region']], axis=1, inplace = True)
# column names
X = df1.columns

# %%
df1.head()
# Out:
#    Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0  12669  9656     7561     214              2674        1338
# 1   7057  9810     9568    1762              3293        1776
# 2   6353  8808     7684    2405              3516        7844
# 3  13265  1196     4221    6404               507        1788
# 4  22615  5410     7198    3915              1777        5185

# %%
# outlier detection with box plot
df1.plot(kind='box', subplots=True, figsize=(20,5), title = 'Outlier Visualization')
plt.show()

# %% [markdown]
# Here presence of outliers is very evident. We are applying Power Transformation method which reduces skewness and varience in data.

# %%
# Fitting Power Transform for outlier handling
# importing PT
from sklearn.preprocessing import PowerTransformer
#instance creation
pt = PowerTransformer(method='yeo-johnson', standardize=True)
# fitting and transforming the model
df1 = pt.fit_transform(df1)

# %%
# Convert array to DataFrame
df1 = pd.DataFrame(df1, columns = X)
# Outlier visualization
df1.plot(kind='box', subplots=True, figsize=(20,5), title='Outlier Visualization')
plt.show()

# %% [markdown]
# The transformed data is again checked for outliers and shows a highly improved performance.
#
# Now that we have completed the handling of outliers, we can Scale the dataset using RobustScaler as it yields better results than StandardScaler in presence of outliers.

# %% [markdown]
# ### Feature Scaling

# %%
# importing RobustScaler for feature scaling
from sklearn.preprocessing import RobustScaler
#instance creation
rc = RobustScaler()
# fitting and transforming the model
df1 = rc.fit_transform(df1)

# %%
# Convert array to DataFrame
df1 = pd.DataFrame(df1, columns = X)
df1.head()
# Out:
#       Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicassen
# 0  0.259493  0.658227  0.297696 -1.143251          0.444476    0.229120
# 1 -0.111342  0.669219  0.455508  0.091833          0.525578    0.439567
# 2 -0.171437  0.594600  0.308367  0.294529          0.551295    1.744429
# 3  0.291425 -0.695738 -0.073821  0.970231         -0.170333    0.444708
# 4  0.695402  0.263624  0.265292  0.623414          0.288021    1.343913

# %% [markdown]
# # **Modelling**
#
# ## **K-Means**

# %%
# KMeans 
# importing KMeans
from sklearn.cluster import KMeans
# instance creation
wcss = [] #creating varable for storing cluster values
for i in np.arange(1,12,1,int):
  K = KMeans(n_clusters=i, init='k-means++',random_state=42)
  K.fit(df1)
  wcss.append(K.inertia_)

# %%
# plot Elbow Method
sns.set_style('darkgrid')
plt.plot(np.arange(1,12,1,int), wcss, marker = '*')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS/Inertia')
plt.title('Elbow Method')
plt.show()

# %% [markdown]
# Number of clusters is identified as 6 from here.

# %% [markdown]
# #### Silhouette Score Validation

# %%
# Importing Silhoutte score
from sklearn.metrics import silhouette_score, silhouette_samples

# %%
range_n_clusters = [2, 3, 4, 5, 6, 7]

for n_clusters in range_n_clusters:
    fig, ax1  = plt.subplots(1, 1)
    fig.set_size_inches(18, 7)

    # The silhouette coefficient can range from -1, 1 but here all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(df1) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=42)
    cluster_labels = clusterer.fit_predict(df1)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(df1, cluster_labels)
    print(
        "For n_clusters =",
        n_clusters,
        "The average silhouette_score is :",
        silhouette_avg,
    )

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(df1, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    
    plt.suptitle(
        "Silhouette analysis for KMeans clustering on Robust Power Transformed data with n_clusters = %d"
        % n_clusters,
        fontsize=14,
        fontweight="bold",
    )

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.2691112627393202
# For n_clusters = 3 The average silhouette_score is : 0.23772594495938484
# For n_clusters = 4 The average silhouette_score is : 0.21779044462939295
# For n_clusters = 5 The average silhouette_score is : 0.19015631827050444
# For n_clusters = 6 The average silhouette_score is : 0.18449754832515966
# For n_clusters = 7 The average silhouette_score is : 0.1828929356590806

# %% [markdown]
# In this case of KMeans, the silhouette score for 6 and 7 clusters seems to be the least. Based on the thickness of the clusters we can select 7.

# %%
# instance creation with no of cluster 6
K = KMeans(n_clusters=6, init='k-means++',random_state=42)
y_pred = K.fit_predict(df1)
df1_k = pd.concat([df1,pd.DataFrame(y_pred)],axis=1)
df1_k
# Out:
#         Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicassen  0
# 0    0.259493  0.658227  0.297696 -1.143251          0.444476    0.229120  0
# 1   -0.111342  0.669219  0.455508  0.091833          0.525578    0.439567  0
# 2   -0.171437  0.594600  0.308367  0.294529          0.551295    1.744429  3
# 3    0.291425 -0.695738 -0.073821  0.970231         -0.170333    0.444708  5
# 4    0.695402  0.263624  0.265292  0.623414          0.288021    1.343913  3
# ..        ...       ...       ...       ...               ...         ... ..
# 435  0.927688  0.813202  0.817816  1.504280         -0.521065    0.607628  3
# 436  1.184684 -0.586703 -1.020338  0.721588         -0.739449    0.657499  5
# 437  0.356036  0.991479  1.296772 -0.750882          1.140792    0.477865  0
# 438  0.120305 -0.385661 -0.450347 -0.240364         -0.547580    0.578740  2
# 439 -0.583346 -0.481495 -0.383198 -1.742602         -0.191804   -1.530730  4
#
# [440 rows x 7 columns]

# %%
pd.crosstab(y_pred,df['Region'])
# Out:
# Region   1   2   3
# row_0
# 0       15  11  61
# 1       13   5  42
# 2       17  10  73
# 3        7   1  29
# 4        7   5  47
# 5       18  15  64

# %%
# instance creation with no of cluster 7
K = KMeans(n_clusters=7, init='k-means++',random_state=42)
y_pred = K.fit_predict(df1)
df1_k1 = pd.concat([df1,pd.DataFrame(y_pred)],axis=1)
df1_k1
# Out:
#         Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicassen  0
# 0    0.259493  0.658227  0.297696 -1.143251          0.444476    0.229120  4
# 1   -0.111342  0.669219  0.455508  0.091833          0.525578    0.439567  4
# 2   -0.171437  0.594600  0.308367  0.294529          0.551295    1.744429  4
# 3    0.291425 -0.695738 -0.073821  0.970231         -0.170333    0.444708  6
# 4    0.695402  0.263624  0.265292  0.623414          0.288021    1.343913  5
# ..        ...       ...       ...       ...               ...         ... ..
# 435  0.927688  0.813202  0.817816  1.504280         -0.521065    0.607628  5
# 436  1.184684 -0.586703 -1.020338  0.721588         -0.739449    0.657499  6
# 437  0.356036  0.991479  1.296772 -0.750882          1.140792    0.477865  4
# 438  0.120305 -0.385661 -0.450347 -0.240364         -0.547580    0.578740  0
# 439 -0.583346 -0.481495 -0.383198 -1.742602         -0.191804   -1.530730  1
#
# [440 rows x 7 columns]

# %%
pd.crosstab(y_pred,df['Region'])
# Out:
# Region   1   2   3
# row_0
# 0        9   8  41
# 1        7   2  26
# 2        8   2  33
# 3        6   5  44
# 4       14  11  65
# 5       11   2  40
# 6       22  17  67

# %% [markdown]
# ## **Hierachichal Agglomerative Clustering**

# %%
# importing Agglomerative Clustering
from sklearn.cluster import AgglomerativeClustering

# %%
# optimum clustering using Dendrogram
from scipy.cluster.hierarchy import dendrogram, linkage
links = linkage(df1,method='ward')
plt.figure(figsize=(16,8))
dendrogram(links, orientation='top', distance_sort ='ascending', show_leaf_counts=True)
plt.hlines(22.5,0,5000, colors='r',  linestyles='dashed')
plt.show()

# %% [markdown]
# In this case of Agglomerative Clustering, the Dendrogram shows ideal no of clusters as 2.

# %% [markdown]
# #### Silhouette Score Validation

# %%
# # Agglomerative Clustering 
range_n_clusters = [2, 3, 4, 5, 6, 7]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, ax1  = plt.subplots(1, 1)
    fig.set_size_inches(14, 6)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(df1) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = AgglomerativeClustering(n_clusters=n_clusters, linkage='ward')
    cluster_labels = clusterer.fit_predict(df1)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(df1, cluster_labels)
    print(
        "For n_clusters =",
        n_clusters,
        "The average silhouette_score is :",
        silhouette_avg,
    )

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(df1, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    
    plt.suptitle(
        "Silhouette analysis for Hierarchical Clustering for Robust Power Transformed data with n_clusters = %d"
        % n_clusters,
        fontsize=14,
        fontweight="bold",
    )

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.24845131247660146
# For n_clusters = 3 The average silhouette_score is : 0.22420630369189665
# For n_clusters = 4 The average silhouette_score is : 0.21703241368359902
# For n_clusters = 5 The average silhouette_score is : 0.1634528960052227
# For n_clusters = 6 The average silhouette_score is : 0.14036518203800527
# For n_clusters = 7 The average silhouette_score is : 0.1369404219239763

# %% [markdown]
# In this case of Agglomerative Clustering, the silhouette score for 6 and 7 clusters seems to be the least. Based on the thickness of the clusters we can select 6.
#
#
#
# If we compare all the details of the 2 Clustering Models, we can come to the following conclusions:
# 1. K-Means Model yields an ideal no of clusters of 6 via Elbow Method. On validation of using silhouette score, we get no of clusters as 7.
#
# 2. Agglomerative Model yields an ideal no of clusters of 2 by using the Dendrogram method and when validation is done using silhouette score, we get no of cluster as 6.
#
# PCA can be used for Dimensionality Reduction which might help us get better results.

# %%
# instance creation with 6 clusters
ahc = AgglomerativeClustering(n_clusters=6, linkage ='ward', affinity='euclidean')
# fitting
y_pred = ahc.fit_predict(df1)
df1_ahc = pd.concat([df1,pd.DataFrame(y_pred)],axis=1)
pd.crosstab(y_pred,df['Region'])
# Out:
# Region   1   2   3
# row_0
# 0       13   6  61
# 1       19  12  78
# 2       25  15  61
# 3        3   3  25
# 4       10   5  44
# 5        7   6  47

# %% [markdown]
# ### PCA - Principal Component Analysis

# %% [markdown]
# #### Case 1 - Varience measure 0.95

# %%
# we can apply PCA only to scaled data here we apply to df1
#Importing PCA
from sklearn.decomposition import PCA
# instance creation
pca = PCA(0.95) # case 1 with varience measure 0.95
# fitting to model
pca_mod = pca.fit_transform(df1)

# %%
pca_mod.shape
# Out:
# (440, 5)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.39890846, 0.31859214, 0.11523625, 0.10466457, 0.04035042])

# %%
# relation btw PCA components and the df cols
pd.DataFrame(pca.components_, columns=df1.columns, 
             index=['PC-1','PC-2','PC-3','PC-4','PC-5'])
# Out:
#          Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicassen
# PC-1  0.054500 -0.563707 -0.557779  0.105034         -0.473298   -0.364834
# PC-2  0.511374  0.035095 -0.076703  0.670416         -0.138797    0.512503
# PC-3  0.005497  0.170981  0.212680  0.603730          0.229834   -0.712873
# PC-4 -0.856384 -0.042580 -0.090816  0.413572         -0.068267    0.284332
# PC-5  0.038609 -0.776607  0.242700  0.062859          0.563731    0.121423

# %% [markdown]
# #### Case 2 - Number of components

# %%
# instance creation
pca1 = PCA(n_components=2) # case 2 with components 2
# fitting to model
pca1_mod = pca1.fit_transform(df1)

# %%
pca1_mod.shape
# Out:
# (440, 2)

# %%
pca1.explained_variance_ratio_
# Out:
# array([0.39890846, 0.31859214])

# %%
# relation btw PCA components and the df cols
pd.DataFrame(pca1.components_, columns=df1.columns, 
             index=['PC-1','PC-2'])
# Out:
#          Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicassen
# PC-1  0.054500 -0.563707 -0.557779  0.105034         -0.473298   -0.364834
# PC-2  0.511374  0.035095 -0.076703  0.670416         -0.138797    0.512503

# %% [markdown]
# ## **K-Means**

# %%
# # Case 1: KMeans with PCA(varience measure=0.95)
# instance creation
wcss = [] #creating varable for storing cluster values
for i in np.arange(1,12,1,int):
  K = KMeans(n_clusters=i, init='k-means++',random_state=42)
  K.fit(pca_mod)
  wcss.append(K.inertia_)

# %%
# plot Elbow Method
sns.set_style('darkgrid')
plt.plot(np.arange(1,12,1,int), wcss, marker = '*')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS/Inertia')
plt.title('Elbow Method')
plt.show()

# %% [markdown]
# Ideal number of clusters is obtained as 6.

# %%
# # Case 2: KMeans with PCA(n_components 2)
# instance creation
wcss = [] #creating varable for storing cluster values
for i in np.arange(1,12,1,int):
  K = KMeans(n_clusters=i, init='k-means++',random_state=42)
  K.fit(pca1_mod)
  wcss.append(K.inertia_)

# %%
# plot Elbow Method
sns.set_style('darkgrid')
plt.plot(np.arange(1,12,1,int), wcss, marker = '*')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS/Inertia')
plt.title('Elbow Method')
plt.show()

# %% [markdown]
# Here also 6 seems to be the ideal number of clusters

# %% [markdown]
# #### Silhouette Score Validation

# %%
# # Case 1: KMeans with PCA(varience measure=0.95)
range_n_clusters = [2, 3, 4, 5, 6, 7]

for n_clusters in range_n_clusters:
    fig, ax1  = plt.subplots(1, 1)
    fig.set_size_inches(18, 7)

    # The silhouette coefficient can range from -1, 1 but here all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(pca_mod) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=42)
    cluster_labels = clusterer.fit_predict(pca_mod)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(pca_mod, cluster_labels)
    print(
        "For n_clusters =",
        n_clusters,
        "The average silhouette_score is :",
        silhouette_avg,
    )

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(pca_mod, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    
    plt.suptitle(
        "Silhouette analysis for KMeans Clustering with PCA(varience measure 0.95) with n_clusters = %d"
        % n_clusters,
        fontsize=14,
        fontweight="bold",
    )

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.2757469314668275
# For n_clusters = 3 The average silhouette_score is : 0.24498327041422166
# For n_clusters = 4 The average silhouette_score is : 0.22511492153531779
# For n_clusters = 5 The average silhouette_score is : 0.1960921139456386
# For n_clusters = 6 The average silhouette_score is : 0.18951252172186545
# For n_clusters = 7 The average silhouette_score is : 0.18518320393128063

# %% [markdown]
# In this case of KMeans with PCA(varience measure=0.95), the silhouette score for 6 and 7 clusters seems to be the least. Based on the thickness of the clusters we can select 7.

# %%
# # Case 2: KMeans with PCA(n_components = 2)
range_n_clusters = [2, 3, 4, 5, 6, 7]

for n_clusters in range_n_clusters:
    fig, ax1  = plt.subplots(1, 1)
    fig.set_size_inches(18, 7)

    # The silhouette coefficient can range from -1, 1 but here all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(pca1_mod) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = KMeans(n_clusters=n_clusters, random_state=42)
    cluster_labels = clusterer.fit_predict(pca1_mod)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(pca1_mod, cluster_labels)
    print(
        "For n_clusters =",
        n_clusters,
        "The average silhouette_score is :",
        silhouette_avg,
    )

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(pca1_mod, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    
    plt.suptitle(
        "Silhouette analysis for KMeans Clustering with PCA(n_components=2) with n_clusters = %d"
        % n_clusters,
        fontsize=14,
        fontweight="bold",
    )

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.384010550889794
# For n_clusters = 3 The average silhouette_score is : 0.36925917380016143
# For n_clusters = 4 The average silhouette_score is : 0.36119440365791383
# For n_clusters = 5 The average silhouette_score is : 0.3420196412100588
# For n_clusters = 6 The average silhouette_score is : 0.3455291297588888
# For n_clusters = 7 The average silhouette_score is : 0.35923490399422237

# %% [markdown]
# In this case of KMeans with PCA(n_components = 2), the silhouette score for 5 and 6 clusters seems to be the least. Based on the thickness of the clusters we can select 5.

# %%
# instance creation with no of cluster 5(n_component=2)
K = KMeans(n_clusters=5, init='k-means++',random_state=42)
y_pred = K.fit_predict(pca1_mod)
df1_k1 = pd.concat([df1,pd.DataFrame(y_pred)],axis=1)
pd.crosstab(y_pred,df['Region'])
# Out:
# Region   1   2   3
# row_0
# 0       12   7  53
# 1       16  11  69
# 2       17   9  71
# 3        6   7  41
# 4       26  13  82

# %%
# instance creation with no of cluster 6(n_component=2)
K = KMeans(n_clusters=6, init='k-means++',random_state=42)
y_pred = K.fit_predict(pca1_mod)
df1_k2 = pd.concat([df1,pd.DataFrame(y_pred)],axis=1)
pd.crosstab(y_pred,df['Region'])
# Out:
# Region   1   2   3
# row_0
# 0        9   1  35
# 1       17   9  64
# 2       16  11  67
# 3       13   4  44
# 4        5   5  43
# 5       17  17  63

# %%
# instance creation with no of cluster 7(varience measure =0.95)
K = KMeans(n_clusters=7, init='k-means++',random_state=42)
y_pred = K.fit_predict(pca_mod)
df1_k3 = pd.concat([df1,pd.DataFrame(y_pred)],axis=1)
pd.crosstab(y_pred,df['Region'])
# Out:
# Region   1   2   3
# row_0
# 0       11   2  40
# 1        5   4  32
# 2       14  10  69
# 3       13   8  57
# 4       18  17  60
# 5        6   4  25
# 6       10   2  33

# %%
# instance creation with no of cluster 6(varience measure =0.95)
K = KMeans(n_clusters=6, init='k-means++',random_state=42)
y_pred = K.fit_predict(pca_mod)
df1_k4 = pd.concat([df1,pd.DataFrame(y_pred)],axis=1)
pd.crosstab(y_pred,df['Region'])
# Out:
# Region   1   2   3
# row_0
# 0       18  15  62
# 1       14  10  69
# 2        7   1  28
# 3        8   5  45
# 4       15  11  60
# 5       15   5  52

# %% [markdown]
# ## **Hierachichal Agglomerative Clustering**

# %%
# # Case 1: Dendrogram with PCA(varience measure=0.95)
# optimum clustering using Dendrogram
links = linkage(pca_mod,method='ward')
plt.figure(figsize=(16,8))
dendrogram(links, orientation='top', distance_sort ='ascending', show_leaf_counts=True)
plt.hlines(22,0,5000, colors='r',  linestyles='dashed')
plt.show()

# %% [markdown]
# In this case of Agglomerative Clustering with PCA(varience measure=0.95), the Dendrogram shows ideal no of clusters as 2.

# %%
# # Case 2: Dendrogram with PCA(n_components = 2)
# optimum clustering using Dendrogram
links = linkage(pca1_mod,method='ward')
plt.figure(figsize=(16,8))
dendrogram(links, orientation='top', distance_sort ='ascending', show_leaf_counts=True)
plt.hlines(22,0,5000, colors='r',  linestyles='dashed')
plt.show()

# %% [markdown]
# In this case of Agglomerative Clustering with PCA(n_components=2), the Dendrogram shows ideal no of clusters as 2.

# %% [markdown]
# #### Silhouette Score Validation

# %%
# # Case 1: Agglomerative Clustering with PCA(varience measure=0.95)
range_n_clusters = [2, 3, 4, 5, 6, 7]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, ax1  = plt.subplots(1, 1)
    fig.set_size_inches(14, 6)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(pca_mod) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = AgglomerativeClustering(n_clusters=n_clusters, linkage='ward')
    cluster_labels = clusterer.fit_predict(pca_mod)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(pca_mod, cluster_labels)
    print(
        "For n_clusters =",
        n_clusters,
        "The average silhouette_score is :",
        silhouette_avg,
    )

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(pca_mod, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    
    plt.suptitle(
        "Silhouette analysis for Hierarchical Clustering with PCA(n_components = 2) with n_clusters = %d"
        % n_clusters,
        fontsize=14,
        fontweight="bold",
    )

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.25464095586631613
# For n_clusters = 3 The average silhouette_score is : 0.23449009921095923
# For n_clusters = 4 The average silhouette_score is : 0.20257573656830077
# For n_clusters = 5 The average silhouette_score is : 0.14831844162701605
# For n_clusters = 6 The average silhouette_score is : 0.15064000560863733
# For n_clusters = 7 The average silhouette_score is : 0.15194123375434418

# %% [markdown]
# In this case of Agglomerative Clustering with PCA(varience measure=0.95), the silhouette score for 5 and 6 clusters seems to be the least. Based on the thickness of the clusters we can select 5.

# %%
# # Case 2: Agglomerative Clustering with PCA(n_components = 2)
range_n_clusters = [2, 3, 4, 5, 6, 7]

for n_clusters in range_n_clusters:
    # Create a subplot with 1 row and 2 columns
    fig, ax1  = plt.subplots(1, 1)
    fig.set_size_inches(14, 6)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example all
    # lie within [-0.1, 1]
    ax1.set_xlim([-0.1, 1])
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(pca1_mod) + (n_clusters + 1) * 10])

    # Initialize the clusterer with n_clusters value and a random generator
    # seed of 10 for reproducibility.
    clusterer = AgglomerativeClustering(n_clusters=n_clusters, linkage='ward')
    cluster_labels = clusterer.fit_predict(pca1_mod)

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(pca1_mod, cluster_labels)
    print(
        "For n_clusters =",
        n_clusters,
        "The average silhouette_score is :",
        silhouette_avg,
    )

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(pca1_mod, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    
    plt.suptitle(
        "Silhouette analysis for Hierarchical Clustering with PCA(n_components = 2) with n_clusters = %d"
        % n_clusters,
        fontsize=14,
        fontweight="bold",
    )

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.3538595130980981
# For n_clusters = 3 The average silhouette_score is : 0.3349095032698264
# For n_clusters = 4 The average silhouette_score is : 0.33857995787468237
# For n_clusters = 5 The average silhouette_score is : 0.29635777354408077
# For n_clusters = 6 The average silhouette_score is : 0.30264718589807105
# For n_clusters = 7 The average silhouette_score is : 0.27551694538255445

# %% [markdown]
# In this case of Agglomerative Clustering with PCA(n_components = 2), the silhouette score for 5 and 7 clusters seems to be the least. Based on the thickness of the clusters we can select 5.

# %%
# instance creation with 2 clusters with n_component=2
ahc = AgglomerativeClustering(n_clusters=2, linkage ='ward', affinity='euclidean')
# fitting
y_pred = ahc.fit_predict(pca1_mod)
df1_ahc4 = pd.concat([df1,pd.DataFrame(y_pred)],axis=1)
pd.crosstab(y_pred,df['Region'])
# Out:
# Region   1   2    3
# row_0
# 0       49  26  172
# 1       28  21  144

# %%
# instance creation with 5 clusters with n_component=2
ahc = AgglomerativeClustering(n_clusters=5, linkage ='ward', affinity='euclidean')
# fitting
y_pred = ahc.fit_predict(pca1_mod)
df1_ahc1 = pd.concat([df1,pd.DataFrame(y_pred)],axis=1)
pd.crosstab(y_pred,df['Region'])
# Out:
# Region   1   2   3
# row_0
# 0       20  12  94
# 1       27  17  96
# 2        9   5  45
# 3        8   9  50
# 4       13   4  31

# %%
# instance creation with 2 clusters with varience measure=0.95
ahc = AgglomerativeClustering(n_clusters=2, linkage ='ward', affinity='euclidean')
# fitting
y_pred = ahc.fit_predict(pca_mod)
df1_ahc3 = pd.concat([df1,pd.DataFrame(y_pred)],axis=1)
pd.crosstab(y_pred,df['Region'])
# Out:
# Region   1   2    3
# row_0
# 0       54  31  203
# 1       23  16  113

# %%
# instance creation with 5 clusters with varience measure=0.95
ahc = AgglomerativeClustering(n_clusters=5, linkage ='ward', affinity='euclidean')
# fitting
y_pred = ahc.fit_predict(pca_mod)
df1_ahc2 = pd.concat([df1,pd.DataFrame(y_pred)],axis=1)
pd.crosstab(y_pred,df['Region'])
# Out:
# Region   1   2   3
# row_0
# 0       16   9  76
# 1       13   9  55
# 2       11   5  51
# 3       10   7  58
# 4       27  17  76

# %%
print('PCA:               Varience Measure=0.95      N_Components=2           No PCA')
print('Clusters of K_Means(Elbow):   6                     6                    6')
print('Clusters of K_Means:          6                     6                    7')
print('Clusters of Dendrogram:       2                     2                    2')
print('Clusters of Agglomerative:    5                     5                    6')
# Out:
# PCA:               Varience Measure=0.95      N_Components=2           No PCA
# Clusters of K_Means(Elbow):   6                     6                    6
# Clusters of K_Means:          6                     6                    7
# Clusters of Dendrogram:       2                     2                    2
# Clusters of Agglomerative:    5                     5                    6
